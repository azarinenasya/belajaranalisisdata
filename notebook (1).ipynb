# %% [markdown]
# # Proyek Analisis Data: Air Quality
# - **Nama:** Azarine Nasya Aziza
# - **Email:** cdcc006d6x2179@student.devacademy.id
# - **ID Dicoding:** aziizaapp

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# ### Pertanyaan Bisnis untuk Dataset Air Quality

# %% [markdown]
# - **Pertanyaan 1:** Bagaimana transisi dari hari kerja (Senin-Jumat) ke akhir pekan (Sabtu-Minggu) memengaruhi penurunan rata-rata tingkat Karbon Monoksida (CO) di pusat kota dan apakah penurunan ini terjadi di semua jam atau hanya pada jam sibuk?
# - **Pertanyaan 2:** Berapa presentasi waktu (dalam jam) dan total hari terjadinya kondisi saat konsentrasi NO2 melampaui 80 µg/m³ bersamaan dengan keceatan angin di bawah 1.5 m/s pada hari kerja selama musim dingin?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# Impor library
# !pip install gdown

import gdown
import zipfile
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.4.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# Impor data
# 1. Mengunduh ZIP file dari Google Drive
# File ID diambil melalui sumber dataset yang diberikan
file_id = '1RhU3gJlkteaAQfyn9XOVAz7a5o1-etgr'
output_zip_path = 'air_quality_data.zip'

print(f"Downloading air quality data (ID: {file_id})")
gdown.download(f'https://drive.google.com/uc?id={file_id}', output_zip_path, quiet=False)
print("Download complete.")

# 2. Membuat direktori untuk mengekstrak dokumen
extract_dir = 'air_quality_data_extracted'
os.makedirs(extract_dir, exist_ok=True)

# 3. Membuka ZIP file
print(f"Extracting contents of {output_zip_path} to {extract_dir}...")
with zipfile.ZipFile(output_zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)
print("Extraction complete.")

# 4. Melihat daftar dataset dan mencari CSV secara rekursif
print("\nMencari file CSV...")
csv_files_paths = []
for root, _, files in os.walk(extract_dir):
    for file in files:
        if file.endswith('.csv'):
            csv_files_paths.append(os.path.join(root, file))

dataframes = {}
if csv_files_paths:
    print("File CSV ditemukan:")
    for path in csv_files_paths:
        print(f"- {path}")
        # Menggunakan nama file sebagai kunci di kamus dataframes
        file_name = os.path.basename(path).replace('.csv', '')
        try:
            dataframes[file_name] = pd.read_csv(path)
            print(f"  '{file_name}' berhasil dimuat. Bentuk: {dataframes[file_name].shape}")
        except Exception as e:
            print(f"  Gagal memuat '{file_name}': {e}")

    if dataframes:
        print("\nSemua data berhasil dimuat ke dalam kamus 'dataframes'.")
        # Untuk kemudahan, set 'df' ke DataFrame pertama yang dimuat (jika ada)
        # Ini akan memastikan sel penilaian sebelumnya masih bisa berfungsi untuk satu df
        # Namun, untuk penilaian seluruhnya, kita akan iterasi 'dataframes'.
        df = next(iter(dataframes.values()))
    else:
        print("Tidak ada DataFrame yang berhasil dimuat.")
        df = None
else:
    print("\nTidak ada file CSV yang ditemukan di direktori hasil ekstraksi.")
    df = None
# Out:
# Downloading air quality data (ID: 1RhU3gJlkteaAQfyn9XOVAz7a5o1-etgr)
# Downloading...
# From: https://drive.google.com/uc?id=1RhU3gJlkteaAQfyn9XOVAz7a5o1-etgr
# To: /content/air_quality_data.zip
# 100%|██████████| 7.96M/7.96M [00:00<00:00, 19.5MB/s]
# Download complete.
# Extracting contents of air_quality_data.zip to air_quality_data_extracted...
# Extraction complete.
#
# Mencari file CSV...
# File CSV ditemukan:
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv
#   'PRSA_Data_Changping_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Aotizhongxin_20130301-20170228.csv
#   'PRSA_Data_Aotizhongxin_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv
#   'PRSA_Data_Dingling_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Tiantan_20130301-20170228.csv
#   'PRSA_Data_Tiantan_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Huairou_20130301-20170228.csv
#   'PRSA_Data_Huairou_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Nongzhanguan_20130301-20170228.csv
#   'PRSA_Data_Nongzhanguan_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Guanyuan_20130301-20170228.csv
#   'PRSA_Data_Guanyuan_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Gucheng_20130301-20170228.csv
#   'PRSA_Data_Gucheng_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Dongsi_20130301-20170228.csv
#   'PRSA_Data_Dongsi_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Wanliu_20130301-20170228.csv
#   'PRSA_Data_Wanliu_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Wanshouxigong_20130301-20170228.csv
#   'PRSA_Data_Wanshouxigong_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
# - air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Shunyi_20130301-20170228.csv
#   'PRSA_Data_Shunyi_20130301-20170228' berhasil dimuat. Bentuk: (35064, 18)
#
# Semua data berhasil dimuat ke dalam kamus 'dataframes'.

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df

# %%
# Membuat variabel baru untuk membaca data dari salah satu file CSV yang diekstrak

changping_file_path = '/content/air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv'
changping_df = pd.read_csv(changping_file_path)

print(f"Data dari {changping_file_path} berhasil dimuat ke variabel 'changping_df'.")
print("Berikut 5 baris pertama dari 'changping_df':")
print(changping_df.head())
# Out:
# Data dari /content/air_quality_data_extracted/PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv berhasil dimuat ke variabel 'changping_df'.
# Berikut 5 baris pertama dari 'changping_df':
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying the problem

# %%
print('--- Assessing Data for All CSV Files ---')

if 'dataframes' in locals() and dataframes:
    for name, df_item in dataframes.items():
        print(f"\n=== {name} ===")
        print('\n--- Informasi DataFrame ---')
        df_item.info()

        print('\n--- Missing Values per Kolom ---')
        print(df_item.isnull().sum())

        print('\n--- Jumlah Data Duplikat ---')
        print(f'Jumlah baris duplikat: {df_item.duplicated().sum()}')

        print('\n--- Statistik Deskriptif untuk Kolom Numerik ---')
        display(df_item.describe())

        print('\n--- Statistik Deskriptif untuk Semua Kolom (termasuk non-numerik) ---')
        display(df_item.describe(include='all'))
else:
    print("Tidak ada DataFrame yang ditemukan untuk dinilai. Pastikan sel loading data sudah dijalankan.")
# Out:
# --- Assessing Data for All CSV Files ---
#
# === PRSA_Data_Changping_20130301-20170228 ===
#
# --- Informasi DataFrame ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# --- Missing Values per Kolom ---
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64
#
# --- Jumlah Data Duplikat ---
# Jumlah baris duplikat: 0
#
# --- Statistik Deskriptif untuk Kolom Numerik ---
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# std       72.326926     83.441738     20.975331     29.519796   1103.056282
# min        2.000000      2.000000      0.285600      1.847700    100.000000
# 25%       18.000000     34.000000      2.000000     22.000000    500.000000
# 50%       46.000000     72.000000      7.000000     36.000000    800.000000
# 75%      100.000000    131.000000     18.000000     60.358200   1400.000000
# max      882.000000    999.000000    310.000000    226.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34460.000000  35011.000000  35014.000000  35011.000000  35013.000000
# mean      57.940003     13.686111   1007.760278      1.505495      0.060366
# std       54.316674     11.365313     10.225664     13.822099      0.752899
# min        0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%       15.636600      3.400000    999.300000    -10.200000      0.000000
# 50%       46.000000     14.700000   1007.400000      1.800000      0.000000
# 75%       80.000000     23.300000   1016.000000     14.200000      0.000000
# max      429.000000     41.400000   1036.500000     27.200000     52.100000
#
#                WSPM
# count  35021.000000
# mean       1.853836
# std        1.309808
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       10.000000
# --- Statistik Deskriptif untuk Semua Kolom (termasuk non-numerik) ---
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#                PM2.5          PM10           SO2           NO2            CO  \
# count   34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       71.099743     94.657871     14.958906     44.182086   1152.301345
# std        72.326926     83.441738     20.975331     29.519796   1103.056282
# min         2.000000      2.000000      0.285600      1.847700    100.000000
# 25%        18.000000     34.000000      2.000000     22.000000    500.000000
# 50%        46.000000     72.000000      7.000000     36.000000    800.000000
# 75%       100.000000    131.000000     18.000000     60.358200   1400.000000
# max       882.000000    999.000000    310.000000    226.000000  10000.000000
#
#                   O3          TEMP          PRES          DEWP          RAIN  \
# count   34460.000000  35011.000000  35014.000000  35011.000000  35013.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       57.940003     13.686111   1007.760278      1.505495      0.060366
# std        54.316674     11.365313     10.225664     13.822099      0.752899
# min         0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%        15.636600      3.400000    999.300000    -10.200000      0.000000
# 50%        46.000000     14.700000   1007.400000      1.800000      0.000000
# 75%        80.000000     23.300000   1016.000000     14.200000      0.000000
# max       429.000000     41.400000   1036.500000     27.200000     52.100000
#
#            wd          WSPM    station
# count   34924  35021.000000      35064
# unique     16           NaN          1
# top       NNW           NaN  Changping
# freq     4776           NaN      35064
# mean      NaN      1.853836        NaN
# std       NaN      1.309808        NaN
# min       NaN      0.000000        NaN
# 25%       NaN      1.000000        NaN
# 50%       NaN      1.500000        NaN
# 75%       NaN      2.300000        NaN
# max       NaN     10.000000        NaN
# === PRSA_Data_Aotizhongxin_20130301-20170228 ===
#
# --- Informasi DataFrame ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# --- Missing Values per Kolom ---
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64
#
# --- Jumlah Data Duplikat ---
# Jumlah baris duplikat: 0
#
# --- Statistik Deskriptif untuk Kolom Numerik ---
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# std       82.135694     95.223005     22.823017     37.116200   1221.436236
# min        3.000000      2.000000      0.285600      2.000000    100.000000
# 25%       22.000000     38.000000      3.000000     30.000000    500.000000
# 50%       58.000000     87.000000      9.000000     53.000000    900.000000
# 75%      114.000000    155.000000     21.000000     82.000000   1500.000000
# max      898.000000    984.000000    341.000000    290.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33345.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      56.353358     13.584607   1011.846920      3.123062      0.067421
# std       57.916327     11.399097     10.404047     13.688896      0.910056
# min        0.214200    -16.800000    985.900000    -35.300000      0.000000
# 25%        8.000000      3.100000   1003.300000     -8.100000      0.000000
# 50%       42.000000     14.500000   1011.400000      3.800000      0.000000
# 75%       82.000000     23.300000   1020.100000     15.600000      0.000000
# max      423.000000     40.500000   1042.000000     28.500000     72.500000
#
#                WSPM
# count  35050.000000
# mean       1.708496
# std        1.204071
# min        0.000000
# 25%        0.900000
# 50%        1.400000
# 75%        2.200000
# max       11.200000
# --- Statistik Deskriptif untuk Semua Kolom (termasuk non-numerik) ---
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#                PM2.5          PM10           SO2           NO2            CO  \
# count   34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       82.773611    110.060391     17.375901     59.305833   1262.945145
# std        82.135694     95.223005     22.823017     37.116200   1221.436236
# min         3.000000      2.000000      0.285600      2.000000    100.000000
# 25%        22.000000     38.000000      3.000000     30.000000    500.000000
# 50%        58.000000     87.000000      9.000000     53.000000    900.000000
# 75%       114.000000    155.000000     21.000000     82.000000   1500.000000
# max       898.000000    984.000000    341.000000    290.000000  10000.000000
#
#                   O3          TEMP          PRES          DEWP          RAIN  \
# count   33345.000000  35044.000000  35044.000000  35044.000000  35044.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       56.353358     13.584607   1011.846920      3.123062      0.067421
# std        57.916327     11.399097     10.404047     13.688896      0.910056
# min         0.214200    -16.800000    985.900000    -35.300000      0.000000
# 25%         8.000000      3.100000   1003.300000     -8.100000      0.000000
# 50%        42.000000     14.500000   1011.400000      3.800000      0.000000
# 75%        82.000000     23.300000   1020.100000     15.600000      0.000000
# max       423.000000     40.500000   1042.000000     28.500000     72.500000
#
#            wd          WSPM       station
# count   34983  35050.000000         35064
# unique     16           NaN             1
# top        NE           NaN  Aotizhongxin
# freq     5140           NaN         35064
# mean      NaN      1.708496           NaN
# std       NaN      1.204071           NaN
# min       NaN      0.000000           NaN
# 25%       NaN      0.900000           NaN
# 50%       NaN      1.400000           NaN
# 75%       NaN      2.200000           NaN
# max       NaN     11.200000           NaN
# === PRSA_Data_Dingling_20130301-20170228 ===
#
# --- Informasi DataFrame ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# --- Missing Values per Kolom ---
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64
#
# --- Jumlah Data Duplikat ---
# Jumlah baris duplikat: 0
#
# --- Statistik Deskriptif untuk Kolom Numerik ---
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# std       72.267723     79.541685     15.519259     26.383882    903.306220
# min        3.000000      2.000000      0.285600      1.026500    100.000000
# 25%       14.000000     26.000000      2.000000      9.000000    300.000000
# 50%       41.000000     60.000000      5.000000     19.000000    600.000000
# 75%       93.000000    117.000000     15.000000     38.000000   1200.000000
# max      881.000000    905.000000    156.000000    205.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33850.000000  35011.000000  35014.000000  35011.000000  35013.000000
# mean      68.548371     13.686111   1007.760278      1.505495      0.060366
# std       53.764424     11.365313     10.225664     13.822099      0.752899
# min        0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%       31.000000      3.400000    999.300000    -10.200000      0.000000
# 50%       61.000000     14.700000   1007.400000      1.800000      0.000000
# 75%       90.000000     23.300000   1016.000000     14.200000      0.000000
# max      500.000000     41.400000   1036.500000     27.200000     52.100000
#
#                WSPM
# count  35021.000000
# mean       1.853836
# std        1.309808
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       10.000000
# --- Statistik Deskriptif untuk Semua Kolom (termasuk non-numerik) ---
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#                PM2.5          PM10           SO2           NO2            CO  \
# count   34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       65.989497     83.739723     11.749650     27.585467    904.896073
# std        72.267723     79.541685     15.519259     26.383882    903.306220
# min         3.000000      2.000000      0.285600      1.026500    100.000000
# 25%        14.000000     26.000000      2.000000      9.000000    300.000000
# 50%        41.000000     60.000000      5.000000     19.000000    600.000000
# 75%        93.000000    117.000000     15.000000     38.000000   1200.000000
# max       881.000000    905.000000    156.000000    205.000000  10000.000000
#
#                   O3          TEMP          PRES          DEWP          RAIN  \
# count   33850.000000  35011.000000  35014.000000  35011.000000  35013.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       68.548371     13.686111   1007.760278      1.505495      0.060366
# std        53.764424     11.365313     10.225664     13.822099      0.752899
# min         0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%        31.000000      3.400000    999.300000    -10.200000      0.000000
# 50%        61.000000     14.700000   1007.400000      1.800000      0.000000
# 75%        90.000000     23.300000   1016.000000     14.200000      0.000000
# max       500.000000     41.400000   1036.500000     27.200000     52.100000
#
#            wd          WSPM   station
# count   34924  35021.000000     35064
# unique     16           NaN         1
# top       NNW           NaN  Dingling
# freq     4776           NaN     35064
# mean      NaN      1.853836       NaN
# std       NaN      1.309808       NaN
# min       NaN      0.000000       NaN
# 25%       NaN      1.000000       NaN
# 50%       NaN      1.500000       NaN
# 75%       NaN      2.300000       NaN
# max       NaN     10.000000       NaN
# === PRSA_Data_Tiantan_20130301-20170228 ===
#
# --- Informasi DataFrame ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# --- Missing Values per Kolom ---
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64
#
# --- Jumlah Data Duplikat ---
# Jumlah baris duplikat: 0
#
# --- Statistik Deskriptif untuk Kolom Numerik ---
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34387.000000  34467.000000  33946.000000  34320.000000  33938.000000
# mean      82.164911    106.363672     14.367615     53.162646   1298.303318
# std       80.921384     89.700157     20.144631     31.946224   1170.593297
# min        3.000000      2.000000      0.571200      2.000000    100.000000
# 25%       22.000000     41.000000      3.000000     28.000000    500.000000
# 50%       59.000000     85.000000      7.000000     47.000000    900.000000
# 75%      113.000000    144.000000     17.000000     71.000000   1600.000000
# max      821.000000    988.000000    273.000000    241.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34221.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      55.984297     13.671490   1012.547419      2.447535      0.064020
# std       59.081528     11.458418     10.266059     13.810696      0.786282
# min        0.428400    -16.800000    987.100000    -35.300000      0.000000
# 25%        8.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%       40.000000     14.600000   1012.200000      3.000000      0.000000
# 75%       81.000000     23.500000   1020.900000     15.000000      0.000000
# max      674.000000     41.100000   1042.000000     28.800000     46.400000
#
#                WSPM
# count  35050.000000
# mean       1.860785
# std        1.280368
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max       10.500000
# --- Statistik Deskriptif untuk Semua Kolom (termasuk non-numerik) ---
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#                PM2.5          PM10           SO2           NO2            CO  \
# count   34387.000000  34467.000000  33946.000000  34320.000000  33938.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       82.164911    106.363672     14.367615     53.162646   1298.303318
# std        80.921384     89.700157     20.144631     31.946224   1170.593297
# min         3.000000      2.000000      0.571200      2.000000    100.000000
# 25%        22.000000     41.000000      3.000000     28.000000    500.000000
# 50%        59.000000     85.000000      7.000000     47.000000    900.000000
# 75%       113.000000    144.000000     17.000000     71.000000   1600.000000
# max       821.000000    988.000000    273.000000    241.000000  10000.000000
#
#                   O3          TEMP          PRES          DEWP          RAIN  \
# count   34221.000000  35044.000000  35044.000000  35044.000000  35044.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       55.984297     13.671490   1012.547419      2.447535      0.064020
# std        59.081528     11.458418     10.266059     13.810696      0.786282
# min         0.428400    -16.800000    987.100000    -35.300000      0.000000
# 25%         8.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%        40.000000     14.600000   1012.200000      3.000000      0.000000
# 75%        81.000000     23.500000   1020.900000     15.000000      0.000000
# max       674.000000     41.100000   1042.000000     28.800000     46.400000
#
#            wd          WSPM  station
# count   34986  35050.000000    35064
# unique     16           NaN        1
# top       ENE           NaN  Tiantan
# freq     3861           NaN    35064
# mean      NaN      1.860785      NaN
# std       NaN      1.280368      NaN
# min       NaN      0.000000      NaN
# 25%       NaN      1.000000      NaN
# 50%       NaN      1.500000      NaN
# 75%       NaN      2.400000      NaN
# max       NaN     10.500000      NaN
# === PRSA_Data_Huairou_20130301-20170228 ===
#
# --- Informasi DataFrame ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# --- Missing Values per Kolom ---
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64
#
# --- Jumlah Data Duplikat ---
# Jumlah baris duplikat: 0
#
# --- Statistik Deskriptif untuk Kolom Numerik ---
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# mean      69.626367     91.482690     12.121553     32.497250   1022.554545
# std       71.224916     83.289578     18.896912     26.489531    898.738241
# min        2.000000      2.000000      0.285600      1.026500    100.000000
# 25%       17.000000     28.000000      2.000000     12.000000    400.000000
# 50%       47.000000     69.000000      4.000000     25.000000    800.000000
# 75%       98.000000    131.000000     14.000000     46.000000   1300.000000
# max      762.000000    993.000000    315.000000    231.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33913.000000  35013.000000  35011.000000  35011.000000  35009.000000
# mean      59.824713     12.445426   1007.598568      2.238619      0.067940
# std       54.605746     11.751103     10.022101     14.052541      0.849046
# min        0.214200    -19.900000    982.800000    -43.400000      0.000000
# 25%       18.000000      2.100000    999.300000     -9.600000      0.000000
# 50%       49.000000     13.600000   1007.300000      2.700000      0.000000
# 75%       83.000000     22.300000   1015.500000     15.300000      0.000000
# max      444.000000     40.300000   1036.500000     29.100000     45.900000
#
#                WSPM
# count  35015.000000
# mean       1.652021
# std        1.199143
# min        0.000000
# 25%        0.900000
# 50%        1.300000
# 75%        2.000000
# max       12.900000
# --- Statistik Deskriptif untuk Semua Kolom (termasuk non-numerik) ---
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#                PM2.5          PM10           SO2           NO2            CO  \
# count   34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       69.626367     91.482690     12.121553     32.497250   1022.554545
# std        71.224916     83.289578     18.896912     26.489531    898.738241
# min         2.000000      2.000000      0.285600      1.026500    100.000000
# 25%        17.000000     28.000000      2.000000     12.000000    400.000000
# 50%        47.000000     69.000000      4.000000     25.000000    800.000000
# 75%        98.000000    131.000000     14.000000     46.000000   1300.000000
# max       762.000000    993.000000    315.000000    231.000000  10000.000000
#
#                   O3          TEMP          PRES          DEWP          RAIN  \
# count   33913.000000  35013.000000  35011.000000  35011.000000  35009.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       59.824713     12.445426   1007.598568      2.238619      0.067940
# std        54.605746     11.751103     10.022101     14.052541      0.849046
# min         0.214200    -19.900000    982.800000    -43.400000      0.000000
# 25%        18.000000      2.100000    999.300000     -9.600000      0.000000
# 50%        49.000000     13.600000   1007.300000      2.700000      0.000000
# 75%        83.000000     22.300000   1015.500000     15.300000      0.000000
# max       444.000000     40.300000   1036.500000     29.100000     45.900000
#
#            wd          WSPM  station
# count   34762  35015.000000    35064
# unique     16           NaN        1
# top        NW           NaN  Huairou
# freq     4943           NaN    35064
# mean      NaN      1.652021      NaN
# std       NaN      1.199143      NaN
# min       NaN      0.000000      NaN
# 25%       NaN      0.900000      NaN
# 50%       NaN      1.300000      NaN
# 75%       NaN      2.000000      NaN
# max       NaN     12.900000      NaN
# === PRSA_Data_Nongzhanguan_20130301-20170228 ===
#
# --- Informasi DataFrame ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# --- Missing Values per Kolom ---
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64
#
# --- Jumlah Data Duplikat ---
# Jumlah baris duplikat: 0
#
# --- Statistik Deskriptif untuk Kolom Numerik ---
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34436.000000  34624.000000  34618.000000  34372.000000  33858.000000
# mean      84.838483    108.991096     18.689242     58.097172   1324.350198
# std       86.225344     95.341177     24.280665     36.297740   1245.166124
# min        2.000000      2.000000      0.571200      2.000000    100.000000
# 25%       22.000000     38.000000      3.000000     29.000000    500.000000
# 50%       59.000000     85.000000      9.000000     51.000000    900.000000
# 75%      116.000000    149.000000     23.000000     80.000000   1600.000000
# max      844.000000    995.000000    257.000000    273.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34558.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      58.534682     13.671490   1012.547419      2.447535      0.064020
# std       58.401448     11.458418     10.266059     13.810696      0.786282
# min        0.214200    -16.800000    987.100000    -35.300000      0.000000
# 25%       10.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%       45.000000     14.600000   1012.200000      3.000000      0.000000
# 75%       84.000000     23.500000   1020.900000     15.000000      0.000000
# max      390.000000     41.100000   1042.000000     28.800000     46.400000
#
#                WSPM
# count  35050.000000
# mean       1.860785
# std        1.280368
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max       10.500000
# --- Statistik Deskriptif untuk Semua Kolom (termasuk non-numerik) ---
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#                PM2.5          PM10           SO2           NO2            CO  \
# count   34436.000000  34624.000000  34618.000000  34372.000000  33858.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       84.838483    108.991096     18.689242     58.097172   1324.350198
# std        86.225344     95.341177     24.280665     36.297740   1245.166124
# min         2.000000      2.000000      0.571200      2.000000    100.000000
# 25%        22.000000     38.000000      3.000000     29.000000    500.000000
# 50%        59.000000     85.000000      9.000000     51.000000    900.000000
# 75%       116.000000    149.000000     23.000000     80.000000   1600.000000
# max       844.000000    995.000000    257.000000    273.000000  10000.000000
#
#                   O3          TEMP          PRES          DEWP          RAIN  \
# count   34558.000000  35044.000000  35044.000000  35044.000000  35044.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       58.534682     13.671490   1012.547419      2.447535      0.064020
# std        58.401448     11.458418     10.266059     13.810696      0.786282
# min         0.214200    -16.800000    987.100000    -35.300000      0.000000
# 25%        10.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%        45.000000     14.600000   1012.200000      3.000000      0.000000
# 75%        84.000000     23.500000   1020.900000     15.000000      0.000000
# max       390.000000     41.100000   1042.000000     28.800000     46.400000
#
#            wd          WSPM       station
# count   34986  35050.000000         35064
# unique     16           NaN             1
# top       ENE           NaN  Nongzhanguan
# freq     3861           NaN         35064
# mean      NaN      1.860785           NaN
# std       NaN      1.280368           NaN
# min       NaN      0.000000           NaN
# 25%       NaN      1.000000           NaN
# 50%       NaN      1.500000           NaN
# 75%       NaN      2.400000           NaN
# max       NaN     10.500000           NaN
# === PRSA_Data_Guanyuan_20130301-20170228 ===
#
# --- Informasi DataFrame ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# --- Missing Values per Kolom ---
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64
#
# --- Jumlah Data Duplikat ---
# Jumlah baris duplikat: 0
#
# --- Statistik Deskriptif untuk Kolom Numerik ---
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# std       80.933497     91.573709     23.600367     35.150857   1164.854945
# min        2.000000      2.000000      1.000000      2.000000    100.000000
# 25%       23.000000     40.000000      3.000000     31.000000    500.000000
# 50%       59.000000     89.000000      8.000000     51.000000    900.000000
# 75%      115.000000    149.000000     22.000000     78.000000   1600.000000
# max      680.000000    999.000000    293.000000    270.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33891.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      55.795044     13.584607   1011.846920      3.123062      0.067421
# std       57.436983     11.399097     10.404047     13.688896      0.910056
# min        0.214200    -16.800000    985.900000    -35.300000      0.000000
# 25%        7.000000      3.100000   1003.300000     -8.100000      0.000000
# 50%       41.000000     14.500000   1011.400000      3.800000      0.000000
# 75%       81.000000     23.300000   1020.100000     15.600000      0.000000
# max      415.000000     40.500000   1042.000000     28.500000     72.500000
#
#                WSPM
# count  35050.000000
# mean       1.708496
# std        1.204071
# min        0.000000
# 25%        0.900000
# 50%        1.400000
# 75%        2.200000
# max       11.200000
# --- Statistik Deskriptif untuk Semua Kolom (termasuk non-numerik) ---
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# ...
# max       957.000000    951.000000    282.000000    264.000000  10000.000000
#
#                   O3          TEMP          PRES          DEWP          RAIN  \
# count   32957.000000  35044.000000  35044.000000  35044.000000  35044.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       48.873614     13.428865   1011.097536      3.266588      0.068263
# std        55.111740     11.346931     10.355247     13.678060      0.896726
# min         0.214200    -15.800000    985.900000    -34.900000      0.000000
# 25%         4.000000      3.200000   1002.500000     -8.100000      0.000000
# 50%        32.000000     14.300000   1010.800000      4.000000      0.000000
# 75%        73.000000     22.900000   1019.400000     15.800000      0.000000
# max       364.000000     40.500000   1040.300000     28.500000     72.500000
#
#            wd          WSPM station
# count   34941  35050.000000   35064
# unique     16           NaN       1
# top        NE           NaN  Wanliu
# freq     6703           NaN   35064
# mean      NaN      1.501215     NaN
# std       NaN      1.104472     NaN
# min       NaN      0.000000     NaN
# 25%       NaN      0.800000     NaN
# 50%       NaN      1.200000     NaN
# 75%       NaN      2.000000     NaN
# max       NaN     11.200000     NaN
# === PRSA_Data_Wanshouxigong_20130301-20170228 ===
#
# --- Informasi DataFrame ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# --- Missing Values per Kolom ---
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64
#
# --- Jumlah Data Duplikat ---
# Jumlah baris duplikat: 0
#
# --- Statistik Deskriptif untuk Kolom Numerik ---
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2          NO2            CO  \
# count  34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# mean      85.024136    112.223459     17.148603     55.52956   1370.395031
# std       85.975981     97.593210     23.940834     35.80805   1223.139114
# min        3.000000      2.000000      0.285600      2.00000    100.000000
# 25%       23.000000     39.000000      3.000000     28.00000    600.000000
# 50%       60.000000     91.000000      8.000000     49.00000   1000.000000
# 75%      116.000000    154.000000     21.000000     77.00000   1700.000000
# max      999.000000    961.000000    411.000000    251.00000   9800.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33986.000000  35045.000000  35045.000000  35045.000000  35045.000000
# mean      56.229904     13.784477   1011.511804      2.707442      0.064320
# std       57.082710     11.385156     10.570928     13.704139      0.796981
# min        0.214200    -16.800000    985.100000    -35.300000      0.000000
# 25%        8.000000      3.400000   1002.800000     -8.500000      0.000000
# 50%       42.000000     14.800000   1011.000000      3.300000      0.000000
# 75%       82.000000     23.500000   1020.000000     15.200000      0.000000
# max      358.000000     40.600000   1042.000000     28.500000     46.400000
#
#                WSPM
# count  35051.000000
# mean       1.745314
# std        1.206355
# min        0.000000
# 25%        0.900000
# 50%        1.400000
# 75%        2.300000
# max       13.200000
# --- Statistik Deskriptif untuk Semua Kolom (termasuk non-numerik) ---
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#                PM2.5          PM10           SO2          NO2            CO  \
# count   34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# unique           NaN           NaN           NaN          NaN           NaN
# top              NaN           NaN           NaN          NaN           NaN
# freq             NaN           NaN           NaN          NaN           NaN
# mean       85.024136    112.223459     17.148603     55.52956   1370.395031
# std        85.975981     97.593210     23.940834     35.80805   1223.139114
# min         3.000000      2.000000      0.285600      2.00000    100.000000
# 25%        23.000000     39.000000      3.000000     28.00000    600.000000
# 50%        60.000000     91.000000      8.000000     49.00000   1000.000000
# 75%       116.000000    154.000000     21.000000     77.00000   1700.000000
# max       999.000000    961.000000    411.000000    251.00000   9800.000000
#
#                   O3          TEMP          PRES          DEWP          RAIN  \
# count   33986.000000  35045.000000  35045.000000  35045.000000  35045.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       56.229904     13.784477   1011.511804      2.707442      0.064320
# std        57.082710     11.385156     10.570928     13.704139      0.796981
# min         0.214200    -16.800000    985.100000    -35.300000      0.000000
# 25%         8.000000      3.400000   1002.800000     -8.500000      0.000000
# 50%        42.000000     14.800000   1011.000000      3.300000      0.000000
# 75%        82.000000     23.500000   1020.000000     15.200000      0.000000
# max       358.000000     40.600000   1042.000000     28.500000     46.400000
#
#            wd          WSPM        station
# count   34985  35051.000000          35064
# unique     16           NaN              1
# top        NE           NaN  Wanshouxigong
# freq     3568           NaN          35064
# mean      NaN      1.745314            NaN
# std       NaN      1.206355            NaN
# min       NaN      0.000000            NaN
# 25%       NaN      0.900000            NaN
# 50%       NaN      1.400000            NaN
# 75%       NaN      2.300000            NaN
# max       NaN     13.200000            NaN
# === PRSA_Data_Shunyi_20130301-20170228 ===
#
# --- Informasi DataFrame ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
# --- Missing Values per Kolom ---
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64
#
# --- Jumlah Data Duplikat ---
# Jumlah baris duplikat: 0
#
# --- Statistik Deskriptif untuk Kolom Numerik ---
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# std       81.231739     89.143718     19.572068     30.996828   1156.374102
# min        2.000000      2.000000      0.285600      2.000000    100.000000
# 25%       19.000000     31.000000      2.000000     19.000000    400.000000
# 50%       55.000000     77.000000      5.000000     37.000000    800.000000
# 75%      112.000000    138.000000     17.000000     62.000000   1500.000000
# max      941.000000    999.000000    239.000000    258.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33575.000000  35013.000000  35013.000000  35010.000000  35013.000000
# mean      55.201321     13.387969   1013.061938      2.465036      0.061094
# std       54.873726     11.483588     10.177339     13.726622      0.761668
# min        0.214200    -16.800000    988.000000    -36.000000      0.000000
# 25%       10.000000      3.000000   1004.700000     -8.800000      0.000000
# 50%       43.000000     14.400000   1012.700000      3.100000      0.000000
# 75%       77.000000     23.200000   1021.000000     15.100000      0.000000
# max      351.716400     40.600000   1042.800000     27.500000     37.300000
#
#                WSPM
# count  35020.000000
# mean       1.807533
# std        1.287817
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       12.800000
# --- Statistik Deskriptif untuk Semua Kolom (termasuk non-numerik) ---
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#                PM2.5          PM10           SO2           NO2            CO  \
# count   34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       79.491602     98.737026     13.572039     43.908865   1187.063979
# std        81.231739     89.143718     19.572068     30.996828   1156.374102
# min         2.000000      2.000000      0.285600      2.000000    100.000000
# 25%        19.000000     31.000000      2.000000     19.000000    400.000000
# 50%        55.000000     77.000000      5.000000     37.000000    800.000000
# 75%       112.000000    138.000000     17.000000     62.000000   1500.000000
# max       941.000000    999.000000    239.000000    258.000000  10000.000000
#
#                   O3          TEMP          PRES          DEWP          RAIN  \
# count   33575.000000  35013.000000  35013.000000  35010.000000  35013.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       55.201321     13.387969   1013.061938      2.465036      0.061094
# std        54.873726     11.483588     10.177339     13.726622      0.761668
# min         0.214200    -16.800000    988.000000    -36.000000      0.000000
# 25%        10.000000      3.000000   1004.700000     -8.800000      0.000000
# 50%        43.000000     14.400000   1012.700000      3.100000      0.000000
# 75%        77.000000     23.200000   1021.000000     15.100000      0.000000
# max       351.716400     40.600000   1042.800000     27.500000     37.300000
#
#            wd          WSPM station
# count   34581  35020.000000   35064
# unique     16           NaN       1
# top       NNE           NaN  Shunyi
# freq     4540           NaN   35064
# mean      NaN      1.807533     NaN
# std       NaN      1.287817     NaN
# min       NaN      0.000000     NaN
# 25%       NaN      1.000000     NaN
# 50%       NaN      1.500000     NaN
# 75%       NaN      2.300000     NaN
# max       NaN     12.800000     NaN

# %% [markdown]
# ### Cleaning Data

# %%
combined_df = pd.concat(dataframes.values(), ignore_index=True)

print("5 baris pertama dari combined_df:")
print(combined_df.head())
print(f"\nBentuk combined_df: {combined_df.shape}")
# Out:
# 5 baris pertama dari combined_df:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping
#
# Bentuk combined_df: (420768, 18)

# %%
if 'year' in combined_df.columns and 'month' in combined_df.columns and 'day' in combined_df.columns and 'hour' in combined_df.columns:
    combined_df['datetime'] = pd.to_datetime(combined_df[['year', 'month', 'day', 'hour']])
    combined_df = combined_df.drop(columns=['year', 'month', 'day', 'hour'])
    print("  -> Kolom 'datetime' berhasil dibuat dan kolom waktu asli dihapus.")
else:
    print("  -> Kolom tahun, bulan, hari, atau jam tidak ditemukan. Kolom 'datetime' diasumsikan sudah ada.")
# Out:
#   -> Kolom 'datetime' berhasil dibuat dan kolom waktu asli dihapus.

# %%
# Membuat kolom turunan untuk 'hari dalam seminggu' dan 'musim'
if 'datetime' in combined_df.columns:
    if 'day_of_week' not in combined_df.columns:
        combined_df['day_of_week'] = combined_df['datetime'].dt.day_name()
        print("  -> Kolom 'day_of_week' berhasil dibuat.")
    else:
        print("  -> Kolom 'day_of_week' sudah ada.")

    if 'is_weekday' not in combined_df.columns:
        combined_df['is_weekday'] = combined_df['datetime'].dt.dayofweek < 5
        print("  -> Kolom 'is_weekday' berhasil dibuat.")
    else:
        print("  -> Kolom 'is_weekday' sudah ada.")

    def get_season(month):
        if month in [12, 1, 2]:
            return 'Winter'
        elif month in [3, 4, 5]:
            return 'Spring'
        elif month in [6, 7, 8]:
            return 'Summer'
        else:
            return 'Autumn'

    if 'season' not in combined_df.columns:
        combined_df['season'] = combined_df['datetime'].dt.month.apply(get_season)
        print("  -> Kolom 'season' berhasil dibuat.")
    else:
        print("  -> Kolom 'season' sudah ada.")
else:
    print("  -> Kolom 'datetime' tidak ditemukan, melewatkan pembuatan kolom turunan waktu.")
# Out:
#   -> Kolom 'day_of_week' berhasil dibuat.
#   -> Kolom 'is_weekday' berhasil dibuat.
#   -> Kolom 'season' berhasil dibuat.

# %%
# Mengidentifikasi dan mengklasifikasikan setiap stasiun sebagai 'pusat kota' atau 'pinggiran'
if 'station' in combined_df.columns and 'location_type' not in combined_df.columns:
    suburban_stations = ['Changping', 'Dingling', 'Huairou', 'Shunyi', 'Wanliu']
    city_center_stations = ['Aotizhongxin', 'Dongsi', 'Guanyuan', 'Gucheng', 'Nongzhanguan', 'Tiantan', 'Wanshouxigong']

    def classify_station_location(station_name):
        if station_name in suburban_stations:
            return 'Suburban'
        elif station_name in city_center_stations:
            return 'City Center'
        else:
            return 'Unknown'

    combined_df['location_type'] = combined_df['station'].apply(classify_station_location)
    print("  -> Kolom 'location_type' untuk stasiun berhasil dibuat.")
else:
    print("  -> Kolom 'location_type' sudah ada atau kolom 'station' tidak ditemukan.")
# Out:
#   -> Kolom 'location_type' untuk stasiun berhasil dibuat.

# %% [markdown]
# #### Fixing lost value

# %%
# Menangani nilai yang hilang (missing values)
print("\n--- Menangani Nilai yang Hilang ---")
print("Jumlah nilai yang hilang sebelum imputasi:")
initial_missing = combined_df.isnull().sum()[combined_df.isnull().sum() > 0]
if not initial_missing.empty:
    print(initial_missing)
else:
    print("Tidak ada nilai yang hilang sebelum imputasi.")

numerical_cols = combined_df.select_dtypes(include=np.number).columns.tolist()
categorical_cols = combined_df.select_dtypes(include='object').columns.tolist()

# Hapus kolom 'No' dari daftar numerik untuk imputasi jika ada
if 'No' in numerical_cols:
    numerical_cols.remove('No')

print("\n  -> Melakukan imputasi kolom numerik dengan median...")
for col in numerical_cols:
    if combined_df[col].isnull().any():
        median_val = combined_df[col].median()
        combined_df[col].fillna(median_val, inplace=True)
        print(f"    Kolom '{col}' diimputasi dengan median: {median_val}")

print("\n  -> Melakukan imputasi kolom kategorikal dengan modus...")
for col in categorical_cols:
    if combined_df[col].isnull().any():
        # Untuk 'wd' yang memiliki missing values, kita isi dengan 'Unknown' agar tidak bias pada modus
        if col == 'wd':
            combined_df[col].fillna('Unknown', inplace=True)
            print(f"    Kolom '{col}' diimputasi dengan 'Unknown'.")
        else:
            mode_val = combined_df[col].mode()[0]
            combined_df[col].fillna(mode_val, inplace=True)
            print(f"    Kolom '{col}' diimputasi dengan modus: {mode_val}")
# Out:
# --- Menangani Nilai yang Hilang ---
# Jumlah nilai yang hilang sebelum imputasi:
# PM2.5     8739
# PM10      6449
# SO2       9021
# NO2      12116
# CO       20701
# O3       13277
# TEMP       398
# PRES       393
# DEWP       403
# RAIN       390
# wd        1822
# WSPM       318
# dtype: int64
#
#   -> Melakukan imputasi kolom numerik dengan median...
#     Kolom 'PM2.5' diimputasi dengan median: 55.0
#     Kolom 'PM10' diimputasi dengan median: 82.0
#     Kolom 'SO2' diimputasi dengan median: 7.0
#     Kolom 'NO2' diimputasi dengan median: 43.0
# /tmp/ipykernel_12582/993632330.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_df[col].fillna(median_val, inplace=True)
#     Kolom 'CO' diimputasi dengan median: 900.0
#     Kolom 'O3' diimputasi dengan median: 45.0
#     Kolom 'TEMP' diimputasi dengan median: 14.5
#     Kolom 'PRES' diimputasi dengan median: 1010.4
#     Kolom 'DEWP' diimputasi dengan median: 3.1
#     Kolom 'RAIN' diimputasi dengan median: 0.0
#     Kolom 'WSPM' diimputasi dengan median: 1.4
#
#   -> Melakukan imputasi kolom kategorikal dengan modus...
# /tmp/ipykernel_12582/993632330.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_df[col].fillna('Unknown', inplace=True)
#     Kolom 'wd' diimputasi dengan 'Unknown'.

# %%
print("\nJumlah nilai yang hilang setelah imputasi:")
missing_after_imputation = combined_df.isnull().sum()[combined_df.isnull().sum() > 0]
if missing_after_imputation.empty:
    print("Tidak ada nilai yang hilang setelah imputasi.")
else:
    print(missing_after_imputation)

print("\n--- Ringkasan DataFrame setelah Preprocessing dan Cleaning ---")
combined_df.info()
print("\n5 baris pertama dari combined_df setelah semua preprocessing:")
print(combined_df.head())
# Out:
# Jumlah nilai yang hilang setelah imputasi:
# Tidak ada nilai yang hilang setelah imputasi.
#
# --- Ringkasan DataFrame setelah Preprocessing dan Cleaning ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   No             420768 non-null  int64
#  1   PM2.5          420768 non-null  float64
#  2   PM10           420768 non-null  float64
#  3   SO2            420768 non-null  float64
#  4   NO2            420768 non-null  float64
#  5   CO             420768 non-null  float64
#  6   O3             420768 non-null  float64
#  7   TEMP           420768 non-null  float64
#  8   PRES           420768 non-null  float64
#  9   DEWP           420768 non-null  float64
#  10  RAIN           420768 non-null  float64
#  11  wd             420768 non-null  object
#  12  WSPM           420768 non-null  float64
#  13  station        420768 non-null  object
#  14  datetime       420768 non-null  datetime64[ns]
#  15  day_of_week    420768 non-null  object
#  16  is_weekday     420768 non-null  bool
#  17  season         420768 non-null  object
#  18  location_type  420768 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(11), int64(1), object(5)
# memory usage: 58.2+ MB
#
# 5 baris pertama dari combined_df setelah semua preprocessing:
#    No  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  DEWP  RAIN   wd  \
# 0   1    3.0   6.0  13.0   7.0  300.0  85.0  -2.3  1020.8 -19.7   0.0    E
# 1   2    3.0   3.0   6.0   6.0  300.0  85.0  -2.5  1021.3 -19.0   0.0  ENE
# 2   3    3.0   3.0  22.0  13.0  400.0  74.0  -3.0  1021.3 -19.9   0.0  ENE
# 3   4    3.0   6.0  12.0   8.0  300.0  81.0  -3.6  1021.8 -19.1   0.0  NNE
# 4   5    3.0   3.0  14.0   8.0  300.0  81.0  -3.5  1022.3 -19.4   0.0    N
#
#    WSPM    station            datetime day_of_week  is_weekday  season  \
# 0   0.5  Changping 2013-03-01 00:00:00      Friday        True  Spring
# 1   0.7  Changping 2013-03-01 01:00:00      Friday        True  Spring
# 2   0.2  Changping 2013-03-01 02:00:00      Friday        True  Spring
# 3   1.0  Changping 2013-03-01 03:00:00      Friday        True  Spring
# 4   2.1  Changping 2013-03-01 04:00:00      Friday        True  Spring
#
#   location_type
# 0      Suburban
# 1      Suburban
# 2      Suburban
# 3      Suburban
# 4      Suburban

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore

# %%
print("\n--- Ringkasan Statistik Data Numerik ---")
display(combined_df.describe())

print("\n--- Ringkasan Statistik Data Kategorikal ---")
display(combined_df.describe(include='object'))

# Agregasi data: Rata-rata polutan berdasarkan musim dan jenis lokasi
print("\n--- Rata-rata Polutan berdasarkan Musim dan Jenis Lokasi ---")
agg_season_location = combined_df.groupby(['season', 'location_type'])[['PM2.5', 'PM10', 'NO2', 'CO', 'O3', 'SO2']].mean().round(2)
display(agg_season_location)

# Agregasi data: Rata-rata polutan berdasarkan hari dalam seminggu
print("\n--- Rata-rata Polutan berdasarkan Hari dalam Seminggu ---")
agg_day_of_week = combined_df.groupby('day_of_week')[['PM2.5', 'PM10', 'NO2', 'CO', 'O3', 'SO2']].mean().round(2)
display(agg_day_of_week)

# Agregasi data: Rata-rata polutan berdasarkan jam dalam sehari
print("\n--- Rata-rata Polutan berdasarkan Jam dalam Sehari ---")
combined_df['hour'] = combined_df['datetime'].dt.hour
agg_hour = combined_df.groupby('hour')[['PM2.5', 'PM10', 'NO2', 'CO', 'O3', 'SO2']].mean().round(2)
display(agg_hour)

# Analisis Korelasi (Multivariate)
print("\n--- Matriks Korelasi antar Variabel Numerik ---")
# Pilih kolom numerik yang relevan untuk korelasi
numerical_cols_for_corr = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']
correlation_matrix = combined_df[numerical_cols_for_corr].corr().round(2)
display(correlation_matrix)

print("\n--- Distribusi Kolom Kategorikal: 'station' ---")
print(combined_df['station'].value_counts())

print("\n--- Distribusi Kolom Kategorikal: 'wd' (arah angin) ---")
print(combined_df['wd'].value_counts())

print("\n--- Distribusi Kolom Kategorikal: 'season' ---")
print(combined_df['season'].value_counts())
# Out:
# --- Ringkasan Statistik Data Numerik ---
#                   No          PM2.5           PM10            SO2  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000      79.278489     104.256193      15.641507
# min         1.000000       2.000000       2.000000       0.285600
# 25%      8766.750000      21.000000      36.000000       3.000000
# 50%     17532.500000      55.000000      82.000000       7.000000
# 75%     26298.250000     109.000000     144.000000      19.000000
# max     35064.000000     999.000000     999.000000     500.000000
# std     10122.116943      80.056799      91.108745      21.455419
#
#                  NO2             CO             O3           TEMP  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean       50.418633    1214.493362      56.981874      13.539885
# min         1.026500     100.000000       0.214200     -19.900000
# 25%        24.000000     500.000000      12.000000       3.100000
# 50%        43.000000     900.000000      45.000000      14.500000
# 75%        70.000000    1500.000000      80.000000      23.200000
# max       290.000000   10000.000000    1071.000000      41.600000
# std        34.642023    1133.542988      55.802413      11.430768
#
#                 PRES           DEWP           RAIN           WSPM  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean     1010.746658       2.491405       0.064416       1.729461
# min       982.400000     -43.400000       0.000000       0.000000
# 25%      1002.300000      -8.900000       0.000000       0.900000
# 50%      1010.400000       3.100000       0.000000       1.400000
# 75%      1019.000000      15.100000       0.000000       2.200000
# max      1042.800000      29.100000      72.500000      13.200000
# std        10.469168      13.787252       0.820626       1.245947
#
#                             datetime
# count                         420768
# mean   2015-03-01 11:30:00.000001024
# min              2013-03-01 00:00:00
# 25%              2014-03-01 05:45:00
# 50%              2015-03-01 11:30:00
# 75%              2016-02-29 17:15:00
# max              2017-02-28 23:00:00
# std                              NaN
# --- Ringkasan Statistik Data Kategorikal ---
#             wd    station day_of_week  season location_type
# count   420768     420768      420768  420768        420768
# unique      17         12           7       4             2
# top         NE  Changping      Friday  Spring   City Center
# freq     43335      35064       60192  105984        245448
# --- Rata-rata Polutan berdasarkan Musim dan Jenis Lokasi ---
#                        PM2.5    PM10    NO2       CO     O3    SO2
# season location_type
# Autumn City Center     86.92  110.59  62.69  1318.48  34.03  10.76
#        Suburban        74.60   93.05  45.52  1097.59  37.16   9.05
# Spring City Center     78.92  124.86  53.86  1041.86  70.00  20.29
#        Suburban        73.12  111.91  44.22   898.46  70.93  16.24
# Summer City Center     67.56   85.13  43.19   963.32  92.35   6.42
#        Suburban        60.12   74.95  28.81   812.08  89.89   5.51
# Winter City Center    100.50  121.30  64.09  1855.03  28.90  30.00
#        Suburban        86.53  102.71  52.65  1626.05  31.87  25.33
# --- Rata-rata Polutan berdasarkan Hari dalam Seminggu ---
#              PM2.5    PM10    NO2       CO     O3    SO2
# day_of_week
# Friday       82.67  106.66  51.87  1252.37  55.59  15.80
# Monday       72.61   97.87  47.89  1127.76  58.57  15.47
# Saturday     86.99  112.93  52.60  1289.06  56.41  16.68
# Sunday       80.22  107.16  49.25  1231.48  59.12  16.13
# Thursday     78.65  103.38  49.66  1191.83  56.76  15.09
# Tuesday      76.47  101.07  50.85  1214.35  56.12  15.56
# Wednesday    77.31  100.70  50.80  1194.40  56.30  14.74
# --- Rata-rata Polutan berdasarkan Jam dalam Sehari ---
#       PM2.5    PM10    NO2       CO      O3    SO2
# hour
# 0     87.09  114.45  57.61  1352.24   42.03  14.89
# 1     86.06  110.73  55.45  1355.86   38.39  14.82
# 2     84.04  106.27  52.98  1299.00   34.60  14.24
# 3     81.51  101.84  52.08  1241.03   32.86  13.51
# 4     78.89   97.47  51.26  1221.88   32.18  13.05
# 5     76.04   93.57  50.52  1234.16   28.92  12.61
# 6     73.94   92.04  50.59  1249.90   27.73  12.60
# 7     72.96   93.57  52.36  1276.09   26.04  13.06
# 8     74.23   98.32  54.02  1321.13   27.60  14.67
# 9     75.70  100.65  52.44  1313.14   34.96  17.17
# 10    76.66  100.59  49.72  1262.05   46.15  18.88
# 11    76.63   99.13  46.62  1201.58   58.99  19.34
# 12    76.12   96.50  43.64  1137.45   72.50  19.11
# 13    75.61   94.76  40.63  1073.71   85.36  18.65
# 14    74.77   94.72  38.73  1021.40   95.00  17.72
# 15    73.96   96.37  38.60  1010.44   99.76  17.25
# 16    73.58   98.71  39.46   992.66  100.81  16.60
# 17    74.89  103.12  42.73  1027.87   97.45  16.00
# 18    77.53  109.90  48.41  1097.65   89.07  15.29
# 19    81.98  116.51  54.39  1189.54   77.86  15.12
# 20    85.96  121.62  58.18  1260.72   66.83  15.20
# 21    88.25  122.84  60.02  1315.87   57.06  15.21
# 22    88.24  120.36  60.26  1337.49   50.02  15.20
# 23    88.08  118.10  59.33  1354.99   45.38  15.21
# --- Matriks Korelasi antar Variabel Numerik ---
#        PM2.5  PM10   SO2   NO2    CO    O3  TEMP  PRES  DEWP  RAIN  WSPM
# PM2.5   1.00  0.88  0.48  0.66  0.77 -0.15 -0.13  0.02  0.11 -0.01 -0.27
# PM10    0.88  1.00  0.46  0.65  0.69 -0.11 -0.10 -0.02  0.07 -0.03 -0.18
# SO2     0.48  0.46  1.00  0.49  0.52 -0.16 -0.32  0.22 -0.26 -0.04 -0.11
# NO2     0.66  0.65  0.49  1.00  0.69 -0.46 -0.27  0.17 -0.03 -0.04 -0.39
# CO      0.77  0.69  0.52  0.69  1.00 -0.30 -0.32  0.18 -0.06 -0.01 -0.29
# O3     -0.15 -0.11 -0.16 -0.46 -0.30  1.00  0.59 -0.44  0.31  0.02  0.29
# TEMP   -0.13 -0.10 -0.32 -0.27 -0.32  0.59  1.00 -0.81  0.82  0.04  0.03
# PRES    0.02 -0.02  0.22  0.17  0.18 -0.44 -0.81  1.00 -0.75 -0.06  0.07
# DEWP    0.11  0.07 -0.26 -0.03 -0.06  0.31  0.82 -0.75  1.00  0.09 -0.30
# RAIN   -0.01 -0.03 -0.04 -0.04 -0.01  0.02  0.04 -0.06  0.09  1.00  0.02
# WSPM   -0.27 -0.18 -0.11 -0.39 -0.29  0.29  0.03  0.07 -0.30  0.02  1.00
# --- Distribusi Kolom Kategorikal: 'station' ---
# station
# Changping        35064
# Aotizhongxin     35064
# Dingling         35064
# Tiantan          35064
# Huairou          35064
# Nongzhanguan     35064
# Guanyuan         35064
# Gucheng          35064
# Dongsi           35064
# Wanliu           35064
# Wanshouxigong    35064
# Shunyi           35064
# Name: count, dtype: int64
#
# --- Distribusi Kolom Kategorikal: 'wd' (arah angin) ---
# wd
# NE         43335
# ENE        34142
# NW         32600
# N          30869
# E          29752
# SW         28756
# NNE        28232
# NNW        25326
# WNW        24375
# ESE        24220
# SSW        22563
# SE         20074
# WSW        20040
# S          19405
# SSE        17694
# W          17563
# Unknown     1822
# Name: count, dtype: int64
#
# --- Distribusi Kolom Kategorikal: 'season' ---
# season
# Spring    105984
# Summer    105984
# Autumn    104832
# Winter    103968
# Name: count, dtype: int64

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana transisi dari hari kerja (Senin-Jumat) ke akhir pekan (Sabtu-Minggu) memengaruhi penurunan rata-rata tingkat Karbon Monoksida (CO) di pusat kota, dan apakah penurunan ini terjadi di semua jam atau hanya pada jam sibuk?

# %%
# 1. Filter data untuk lokasi pusat kota
city_center_df = combined_df[combined_df['location_type'] == 'City Center'].copy()

# 2. Definisikan kategori hari: hari kerja dan akhir pekan
city_center_df['day_type'] = city_center_df['is_weekday'].apply(lambda x: 'Weekday' if x else 'Weekend')

# 3. Definisikan jam sibuk dan non-sibuk
rush_hour_morning = (city_center_df['hour'] >= 7) & (city_center_df['hour'] < 10)
rush_hour_evening = (city_center_df['hour'] >= 16) & (city_center_df['hour'] < 19)
city_center_df['is_rush_hour'] = rush_hour_morning | rush_hour_evening

# 4. Analisis rata-rata CO berdasarkan hari kerja/akhir pekan untuk semua jam
print("\n--- Rata-rata CO di Pusat Kota (Semua Jam) ---")
co_all_hours = city_center_df.groupby('day_type')['CO'].mean().reset_index()
print(co_all_hours)

# 5. Analisis rata-rata CO berdasarkan hari kerja/akhir pekan untuk jam sibuk
print("\n--- Rata-rata CO di Pusat Kota (Jam Sibuk) ---")
co_rush_hours = city_center_df[city_center_df['is_rush_hour']].groupby('day_type')['CO'].mean().reset_index()
print(co_rush_hours)

# 6. Analisis rata-rata CO berdasarkan hari kerja/akhir pekan untuk jam non-sibuk
print("\n--- Rata-rata CO di Pusat Kota (Jam Non-Sibuk) ---")
co_non_rush_hours = city_center_df[~city_center_df['is_rush_hour']].groupby('day_type')['CO'].mean().reset_index()
print(co_non_rush_hours)
# Out:
# --- Rata-rata CO di Pusat Kota (Semua Jam) ---
#   day_type           CO
# 0  Weekday  1274.358450
# 1  Weekend  1335.743905
#
# --- Rata-rata CO di Pusat Kota (Jam Sibuk) ---
#   day_type           CO
# 0  Weekday  1225.441104
# 1  Weekend  1268.364035
#
# --- Rata-rata CO di Pusat Kota (Jam Non-Sibuk) ---
#   day_type           CO
# 0  Weekday  1290.664232
# 1  Weekend  1358.203862

# %% [markdown]
# ### Visualisasi untuk Pertanyaan 1

# %%
co_hourly_pattern = city_center_df.groupby(['day_type', 'hour'])['CO'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=co_hourly_pattern, x='hour', y='CO', hue='day_type', marker='o')
plt.title('Rata-rata Konsentrasi CO per Jam di Pusat Kota: Hari Kerja vs Akhir Pekan')
plt.xlabel('Jam dalam Sehari')
plt.ylabel('Rata-rata Konsentrasi CO (µg/m³)')
plt.xticks(range(0, 24))
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Jenis Hari')
plt.show()

# Tambahan: Menghitung persentase penurunan
print("\n--- Penurunan Rata-rata CO dari Hari Kerja ke Akhir Pekan ---")
if not co_all_hours.empty and 'Weekday' in co_all_hours['day_type'].values and 'Weekend' in co_all_hours['day_type'].values:
    co_weekday_all = co_all_hours[co_all_hours['day_type'] == 'Weekday']['CO'].iloc[0]
    co_weekend_all = co_all_hours[co_all_hours['day_type'] == 'Weekend']['CO'].iloc[0]
    if co_weekday_all > 0:
        percentage_decrease_all = ((co_weekday_all - co_weekend_all) / co_weekday_all) * 100
        print(f"Penurunan CO rata-rata di semua jam: {percentage_decrease_all:.2f}%")

if not co_rush_hours.empty and 'Weekday' in co_rush_hours['day_type'].values and 'Weekend' in co_rush_hours['day_type'].values:
    co_weekday_rush = co_rush_hours[co_rush_hours['day_type'] == 'Weekday']['CO'].iloc[0]
    co_weekend_rush = co_rush_hours[co_rush_hours['day_type'] == 'Weekend']['CO'].iloc[0]
    if co_weekday_rush > 0:
        percentage_decrease_rush = ((co_weekday_rush - co_weekend_rush) / co_weekday_rush) * 100
        print(f"Penurunan CO rata-rata pada jam sibuk: {percentage_decrease_rush:.2f}%")

if not co_non_rush_hours.empty and 'Weekday' in co_non_rush_hours['day_type'].values and 'Weekend' in co_non_rush_hours['day_type'].values:
    co_weekday_non_rush = co_non_rush_hours[co_non_rush_hours['day_type'] == 'Weekday']['CO'].iloc[0]
    co_weekend_non_rush = co_non_rush_hours[co_non_rush_hours['day_type'] == 'Weekend']['CO'].iloc[0]
    if co_weekday_non_rush > 0:
        percentage_decrease_non_rush = ((co_weekday_non_rush - co_weekend_non_rush) / co_weekday_non_rush) * 100
        print(f"Penurunan CO rata-rata pada jam non-sibuk: {percentage_decrease_non_rush:.2f}%")
# Out:
# --- Penurunan Rata-rata CO dari Hari Kerja ke Akhir Pekan ---
# Penurunan CO rata-rata di semua jam: -4.82%
# Penurunan CO rata-rata pada jam sibuk: -3.50%
# Penurunan CO rata-rata pada jam non-sibuk: -5.23%

# %% [markdown]
# **Insight:**
#
# **Rata-rata Konsentrasi CO:**
#
# * Secara keseluruhan: Konsentrasi CO rata-rata di
# pusat kota justru meningkat dari hari kerja (1274.36 µg/m³) ke akhir pekan (1335.74 µg/m³). Ini menunjukkan kenaikan sekitar 4.82%.
# * Jam Sibuk: Sama halnya, pada jam sibuk (07:00-09:00 dan 16:00-18:00), CO juga meningkat dari hari kerja (1225.44 µg/m³) ke akhir pekan (1268.36 µg/m³), dengan kenaikan sekitar 3.50%.
# * Jam Non-Sibuk: Peningkatan terbesar terjadi pada jam non-sibuk, di mana CO naik dari hari kerja (1290.66 µg/m³) ke akhir pekan (1358.20 µg/m³), dengan kenaikan sekitar 5.23%.

# %% [markdown]
# ### Pertanyaan 2: Berapa presentasi waktu (dalam jam) dan total hari terjadinya kondisi saat konsentrasi NO2 melampaui 80 µg/m³ bersamaan dengan keceatan angin di bawah 1.5 m/s pada hari kerja selama musim dingin?

# %%
# Filter data untuk hari kerja di musim dingin
winter_weekday_df = combined_df[(combined_df['is_weekday'] == True) & (combined_df['season'] == 'Winter')].copy()

# Total jam dan hari unik yang diamati selama hari kerja di musim dingin
total_winter_weekday_hours = len(winter_weekday_df)
total_winter_weekday_days = winter_weekday_df['datetime'].dt.date.nunique()

print(f"Data difilter untuk hari kerja di musim dingin. Jumlah data: {len(winter_weekday_df)} baris.")
print(f"Total jam di hari kerja musim dingin: {total_winter_weekday_hours}")
print(f"Total hari unik di hari kerja musim dingin: {total_winter_weekday_days}")

# Mengidentifikasi data di mana konsentrasi NO2 > 80 µg/m³ DAN kecepatan angin (WSPM) < 1.5 m/s
condition_met_df = winter_weekday_df[
    (winter_weekday_df['NO2'] > 80) &
    (winter_weekday_df['WSPM'] < 1.5)
].copy()

print(f"Data memenuhi kondisi NO2 > 80 µg/m³ dan WSPM < 1.5 m/s: {len(condition_met_df)} baris.")

# Menghitung total jam (jumlah baris) yang memenuhi kondisi ini
total_hours_condition_met = len(condition_met_df)
print(f"Total jam yang memenuhi kondisi: {total_hours_condition_met}")

# Menghitung total hari unik yang memenuhi kondisi ini
total_days_condition_met = condition_met_df['datetime'].dt.date.nunique()
print(f"Total hari unik yang memenuhi kondisi: {total_days_condition_met}")

# Menghitung persentase jam dan hari tersebut terhadap total jam dan hari yang diamati selama hari kerja di musim dingin
percentage_hours = (total_hours_condition_met / total_winter_weekday_hours) * 100 if total_winter_weekday_hours > 0 else 0
percentage_days = (total_days_condition_met / total_winter_weekday_days) * 100 if total_winter_weekday_days > 0 else 0

print(f"\nPersentase waktu (dalam jam) kondisi terpenuhi: {percentage_hours:.2f}%")
print(f"Persentase total hari kondisi terpenuhi: {percentage_days:.2f}%")
# Out:
# Data difilter untuk hari kerja di musim dingin. Jumlah data: 74592 baris.
# Total jam di hari kerja musim dingin: 74592
# Total hari unik di hari kerja musim dingin: 259
# Data memenuhi kondisi NO2 > 80 µg/m³ dan WSPM < 1.5 m/s: 15627 baris.
# Total jam yang memenuhi kondisi: 15627
# Total hari unik yang memenuhi kondisi: 224
#
# Persentase waktu (dalam jam) kondisi terpenuhi: 20.95%
# Persentase total hari kondisi terpenuhi: 86.49%

# %% [markdown]
# ### Visualisasi untuk Pertanyaan 2

# %%
plt.figure(figsize=(15, 7))
sns.lineplot(data=winter_weekday_df, x='datetime', y='NO2', label='NO2 Concentration (µg/m³)', color='red')
sns.lineplot(data=winter_weekday_df, x='datetime', y='WSPM', label='Wind Speed (m/s)', color='blue')

# Highlight periods where critical conditions are met
for idx, row in condition_met_df.iterrows():
    plt.axvspan(row['datetime'], row['datetime'] + pd.Timedelta(hours=1), color='yellow', alpha=0.3, lw=0)

plt.title('NO2 Concentration and Wind Speed during Winter Weekdays with Critical Conditions Highlighted')
plt.xlabel('Date and Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# **Insight:**
#
#  **Data Terfilter:** Analisis berfokus pada **74,592 jam** di **259 hari unik** yang diklasifikasikan sebagai hari kerja musim dingin.
# *   **Kejadian Kondisi Kritis:** Kondisi kritis spesifik di mana konsentrasi NO2 melebihi 80 µg/m³ dan kecepatan angin (WSPM) di bawah 1.5 m/s terjadi selama:
#     *   **Total Jam:** 15,627 jam
#     *   **Total Hari Unik:** 224 hari
# *   **Persentase Kejadian:**
#     *   Kondisi tersebut terjadi dalam **20.95%** dari total jam hari kerja musim dingin.
#     *   Kondisi tersebut terjadi pada **86.49%** dari total hari kerja musim dingin.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:**
# Berdasarkan analisis, rata-rata konsentrasi Karbon Monoksida (CO) di pusat kota menunjukkan peningkatan dari hari kerja ke akhir pekan. Peningkatan ini terjadi baik pada jam sibuk maupun jam non-sibuk, dengan kenaikan sekitar 4.82% secara keseluruhan, 3.50% pada jam sibuk, dan 5.23% pada jam non-sibuk. Hal ini mengindikasikan bahwa aktivitas di akhir pekan di pusat kota, meskipun mungkin berbeda sifatnya, tetap berkontribusi pada peningkatan kadar CO, bukan penurunan seperti yang mungkin diasumsikan.
#
# - **Conclusion pertanyaan 2:** Selama hari kerja musim dingin, kondisi kritis konsentrasi NO2 tinggi (di atas 80 µg/m³) yang disertai dengan kecepatan angin rendah (di bawah 1.5 m/s) sering terjadi. Meskipun kondisi ini menyumbang sekitar **21% dari total jam**, namun berdampak pada **86.5% dari semua hari kerja musim dingin** yang substansial. Persentase hari yang tinggi ini menunjukkan bahwa kondisi lingkungan seperti itu merupakan karakteristik hari kerja musim dingin dan kemungkinan berkontribusi pada tantangan kualitas udara yang persisten, karena kecepatan angin yang rendah menghambat penyebaran polutan. Investigasi lebih lanjut mengenai waktu spesifik dalam sehari di mana kondisi ini paling sering terjadi dapat memberikan wawasan yang lebih terarah.

# %% [markdown]
# **Rekomendasi Action Item:**
#
# Berdasarkan analisis kualitas udara di stasiun perkotaan dan pinggiran kota, serta kondisi NO2 tinggi saat kecepatan angin rendah di musim dingin, berikut adalah beberapa rekomendasi aksi:
#
# 1.  **Penguatan Kebijakan Transportasi dan Emisi:** Menerapkan kebijakan yang lebih ketat terkait standar emisi kendaraan, terutama di pusat kota, dan mempromosikan secara aktif penggunaan transportasi publik, sepeda, serta kendaraan listrik. Ini dapat membantu mengurangi konsentrasi NO2 dan CO pada jam sibuk.
# 2.  **Sistem Peringatan Dini Kualitas Udara yang Lebih Proaktif:** Mengembangkan dan mengimplementasikan sistem peringatan dini yang tidak hanya memberikan informasi real-time, tetapi juga prediksi kualitas udara, khususnya untuk kondisi 'NO2 tinggi dan angin rendah' selama musim dingin. Peringatan ini harus mencakup saran tindakan bagi warga (misalnya, mengurangi aktivitas luar ruangan, menggunakan masker).
# 3.  **Pengembangan Infrastruktur Hijau:** Berinvestasi dalam peningkatan ruang hijau dan vegetasi di area perkotaan yang padat. Tumbuhan dapat membantu menyaring polutan udara dan meningkatkan kualitas udara secara alami.
# 4.  **Penelitian Lanjutan tentang Sumber Emisi Lokal:** Melakukan studi lebih lanjut untuk mengidentifikasi sumber emisi spesifik (selain kendaraan) yang mungkin berkontribusi terhadap tingkat polusi tinggi di pusat kota, serta mencari solusi mitigasi yang ditargetkan.

# %%
combined_df.to_csv('air_quality_combined.csv', index=False)
print('Data combined_df berhasil disimpan ke air_quality_combined.csv')
# Out:
# Data combined_df berhasil disimpan ke air_quality_combined.csv
